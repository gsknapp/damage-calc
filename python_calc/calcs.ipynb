# %%
import calc,pokemon,move,field

# %%
gengar = pokemon.Pokemon(name="gengar",
                         level=100,
                         item="Choice Specs",
                         nature="Timid",
                         evs={"spa" : 252},
                         boosts={'spa':1},
                         gen=9)

# %%
chansey = pokemon.Pokemon(name="chansey",
                          item="Eviolite",
                          nature="Calm",
                          evs={"hp" : 252, "spd" : 252},
                          gen=9)

# %%
palafin = pokemon.Pokemon(name="Palafin-Hero",gen=9,level=100)

# %%
move = move.Move(name="Flip Turn", gen=9)

# %%
calc.calculate(gen=9,attacker=palafin,defender=chansey,move=move)
# Out:
# {'gen': 9,
#  'attacker': {'name': 'Palafin-Hero',
#   'ability': 'Zero to Hero',
#   'item': None,
#   'level': 100,
#   'nature': 'Serious',
#   'types': ['Water'],
#   'stats': {'hp': 341,
#    'atk': 356,
#    'def': 230,
#    'spa': 248,
#    'spd': 210,
#    'spe': 236},
#   'rawStats': {'hp': 341,
#    'atk': 356,
#    'def': 230,
#    'spa': 248,
#    'spd': 210,
#    'spe': 236},
#   'boosts': {'hp': 0, 'atk': 0, 'def': 0, 'spa': 0, 'spd': 0, 'spe': 0},
#   'originalCurHP': 341,
#   'isDynamaxed': False,
#   'teraType': None,
#   'status': '',
#   'toxicCounter': 0},
#  'defender': {'name': 'chansey',
#   'ability': 'Natural Cure',
#   'item': 'Eviolite',
#   'level': 100,
#   'nature': 'Calm',
#   'types': ['Normal'],
#   'stats': {'hp': 704,
#    'atk': 41,
#    'def': 46,
#    'spa': 106,
#    'spd': 339,
#    'spe': 136},
#   'rawStats': {'hp': 704,
#    'atk': 41,
#    'def': 46,
#    'spa': 106,
#    'spd': 339,
#    'spe': 136},
# ...
